# %%
# Mount Google drive to upload datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# cd into the folder where yolov5 has been cloned
# %cd /content/drive/My Drive/yolov5
# Out:
# /content/drive/My Drive/yolov5

# %%
# The path to the data on my drive
D = '/content/drive/My Drive/yolov5'

# %%
# !pip install -qr 'requirements.txt'
# Out:
#      |████████████████████████████████| 596 kB 11.9 MB/s

# %%
import glob

# Verify that the unlabeled data has been added
len(glob.glob('/content/drive/My Drive/yolov5/customdata/images/train/*'))
# Out:
# 9233

# %%
len(glob.glob('/content/drive/My Drive/yolov5/customdata/labels/val/*'))
# Out:
# 1026

# %%
len(glob.glob('/content/drive/My Drive/yolov5/customdata/labels/test/*'))
# Out:
# 1033

# %%
# Train the model, keeping the backbone frozen to retain Coco pretraining
# !python train.py --img 640 --batch 32 --epochs 100 --data data/bcc.yaml --weights 'yolov5s.pt' --device 0 --cache --freeze 10 --project 'yolov_runs' --name frozen_w_coco_unlabeled
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/bcc.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov_runs, name=frozen_w_coco_unlabeled, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 28 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-275-g29d79a6 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/yolov5

# %%
# Package the fine-tuned model as an onnx file for prediction with torch hub
# !python export.py --weights yolov_runs/frozen_w_coco_unlabeled2/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['yolov_runs/frozen_w_coco_unlabeled2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v6.1-275-g29d79a6 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from yolov_runs/frozen_w_coco_unlabeled2/weights/best.pt with output shape (1, 25200, 8) (13.8 MB)
#
# TorchScript: starting export with torch 1.12.0+cu113...
# TorchScript: export success, saved as yolov_runs/frozen_w_coco_unlabeled2/weights/best.torchscript (27.2 MB)
# requirements: onnx not found and is required by YOLOv5, attempting auto-update...
# ...
