# %% [markdown]
# ## Week 6 Assignment - W200 Introduction to Data Science Programming, UC Berkeley MIDS
#
# Write code in this Jupyter Notebook to solve each of the following problems. Each problem should have its solution in a separate cell. Please upload this **notebook**, your **scrabble.py** file, the **sowpods.txt** file, and your **score_word** module to your GitHub repository in your SUBMISSIONS/week_06 folder by 11:59PM PST the night before class.

# %% [markdown]
# ## Objectives:
#
# - Read and understand PEP 8 standards
# - Use all of your previously gained knowledge together on a single program
# - Demonstrate how to import a user made module and function into python from another .py file
# - Demonstrate how to input command line arguments into a .py file

# %% [markdown]
# ## 6-1. PEP 8 Style Guide (reading and response) (10 points)
#
# Your first task for this week is to write a **250 word reading response** to the article referenced below. In addition, please list **3 questions** that you have from the article (the questions do not count towards the 250 word requirement). Please write your response in the markdown cell below.
#
# The writing response is a free response, so you may write about your reactions, such as an interesting thing that you saw in the article, something that really stuck out to you, etc.
#
# **Article**: [The PEP 8 Style Guide](https://www.python.org/dev/peps/pep-0008). This document is really important for Python coders because it describes best practices and customs.

# %% [markdown]
# YOUR ANSWER HERE
#
# It was interesting to know that code is usually read more often than written. This is mainly due to trying to understand the readability of code and making sure the code is consistent throughout the entire program. As someone who has previously struggled with long lines of code especially in multiple with-statements, it was very insightful to consider limiting all lines to 79 characters and wrapping expressions in parentheses along with backslashes in order to avoid line continuation. Also as someone who is used to line breaking after each binary operator, I have noticed that the readability of code improves when placing operators before the operand per line break. Moreover for code that involves trailing whitespaces, I was able to understand how appropriate it would be to input the same amount of whitespaces on both sides of a binary operator and avoid using too many whitespaces within parentheses, brackets, or braces in order to avoid confusion. For example, there is no need to add spaces around the "=" sign to indicate a keyword argument for a function parameter unless the argument is combined with a default value. It was also very helpful to gain insights around distinguishing different naming styles, especially using short, all-lowercase names for modules and CapWords for class names. Naming conventions are always a major topic for large programs due to confusion around similar names, especially for cases that involves a function argument's name clashing with a reserved keyword, and learned that it is generally better to append a single trailing underscore or use a synonym rather than using an abbreviation or spelling corruption. For me, one of the most useful takeways was knowing that there are six operations (__eq__,__ne__,__lt__,__le__,__gt__,__ge__) along with the functools.total_ordering() decorator that provides a rich combination of tools for comparison purposes, which will come in handy if I ever need to compare classes or functions for code redundancies.
#
# Below are my 3 questions from the article:
#
# 1.) If the Python standard library must use ASCII-only identifiers and use English words wherever feasible, what are the best practices for implementing a transliteration for code that incorporates characters in other languages (e.g. Korean, Chinese, Russian, Spanish, etc.)?
#
# 2.) Knowing that there are different ways to add comments in Python code, what are the situations when it would be better to use comments versus block comments versus inline comments?
#
# 3.) If it is best practice to limit use of the bare 'except' clauses, what are some cases that would require the bare except clause over except Exception and why?

# %% [markdown]
# ## 6-2. Cheating at Scrabble (90 points + 10 Extra Credit Points)
#
# Write a Python program that takes a Scrabble rack as a command-line argument and prints all "valid Scrabble English" words that can be constructed from that rack, along with their Scrabble scores, sorted by score. "valid Scrabble English" words are provided in the data source below. A Scrabble rack is made up of 2 to 7 characters.
#
# Below are the requirements for the program:
# - This needs to be able to be run as a command line tool as shown below (not an input statement!)
# - Name the python file: `scrabble.py`
# - Make a separate module named `wordscore` which contains at a minimum a function called `score_word`. This `score_word` function will take each word and return the score (scoring dictionary is described below). Import this function into your main `scrabble.py` program.
# - Allow anywhere from 2-7 character tiles (letters A-Z) to be inputted.
# - Do not restrict the number of same tiles (e.g., a user is allowed to input ZZZZZQQ).
# - Output the **total** list of valid Scrabble words that can be constructed from the rack as (score, word) tuples, sorted by the score and then by the word alphabetically as shown in the first example below.
# - Then output 'Total number of words:' and the total number.
# - You need to handle input errors from the user and suggest what that error might be caused by and how to fix it (i.e., a helpful error message)
# - Implement wildcards as either `*` or `?`. There can be a total of **only** two wild cards in any user input (that is, one of each character: one `*` and one `?`). Only use the `*` and `?` as wildcard characters. A wildcard character can take any value A-Z. Replace the wildcard symbol with the letter in your answer (see the second example below).
# - Wildcard characters are scored as 0 points, just like in the real Scrabble game. A two wildcard word can be made, should be outputted and scored as 0 points.
#   - In a wildcard case where the same word can be made with or without the wildcard, display the highest score. For example: given the input 'I?F', the word 'if' can be made with the wildcard '?F' as well as the letters 'IF'. Since using the letters 'IF' scores higher, display that score.
# - For partial credit, your program should take less than one minute to run with 2 wildcards in the input. For full credit, the program needs to run with 2 wildcards in less than 30 seconds.
# - Write docstrings for the functions and puts comments in your code.
# - You may only use the Python standard library in this assignment. However, any function in the standard library is allowed.
#
# An example invocation and output:
# ```
# $ python scrabble.py "ZAEFIEE"
# (17, feaze)
# (17, feeze)
# (16, faze)
# (15, fez)
# (15, fiz)
# (12, zea)
# (12, zee)
# (11, za)
# (6, fae)
# (6, fee)
# (6, fie)
# (5, ef)
# (5, fa)
# (5, fe)
# (5, if)
# (2, ae)
# (2, ai)
# (2, ea)
# (2, ee)
# Total number of words: 19
# ```
#
# An example wildcard invocation and output:
# ```
# $ python scrabble.py "?F"
# (4, ef)
# (4, fa)
# (4, fe)
# (4, fy)
# (4, if)
# (4, of)
# Total number of words: 6
# ```
#
# #### Extra Credit (+10 points):
# Requirements:
# - Allow a user to specify that a certain letter has to be at a certain location. For the extra credit, locations of certain letters must be specified at the command line, and may not be some sort of user prompt. How you do this is up to you!
# - This needs to be included and called from your regular scrabble.py file and work with the base requirements above. That is, your program must work with or without the extra credit portion and the extra credit cannot be in a different .py file.
# - Please put comments, any assumptions you made, and a sample of how to run your extra credit in the extra credit cell of this notebook below - it is the last cell. If there is not an example of how to run the extra credit in this cell we will assume that you did not do the extra credit part!
#
# #### The Data
# The file: http://courses.cms.caltech.edu/cs11/material/advjava/lab1/sowpods.zip or https://drive.google.com/file/d/1ewUiZL_4HanCDsaYB5pcKEgqjMFVgGnh/view?usp=sharing contains all "valid Scrabble English" words in the official words list, one word per line. You should download the word file and keep it in your repository so that the program is standalone (instead of accessing it over the web from Python).
#
# You can read data from a text file with the following code:
# ```
# with open("sowpods.txt","r") as infile:
#     raw_input = infile.readlines()
#     data = [datum.strip('\n') for datum in raw_input]
# ```
#
# This will show the first 6 words:
# ```
# print(data[0:6])
# ```
# Please use the dictionary below containing the letters and their Scrabble values:
# ```
# scores = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2,
#          "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3,
#          "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,
#          "r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,
#          "x": 8, "z": 10}
# ```
#
# #### Tips:
# - If you don't know what "scrabble" is or the basic background of the game please look it up online!
# - We recommend that you try to break down the problem into steps on your own before writing any code. Once you've scoped generally what you want to do, then start writing some code.  If you get stuck, go back to thinking about the problem rather than trying to fix lots of errors at the code level.
# - If you have questions on getting arguments from the command line, please review async video 6.17 and Drill 6.18.
# - If you keep getting stuck, then check out: https://wiki.openhatch.org/wiki/Scrabble_challenge or https://drive.google.com/file/d/1g3yz5ljkzaAeQ-AgQR1Hofy8ZJ0jo25x/view?usp=sharing. This is where we got the idea for this assignment and it provides some helpful tips for guiding you along the way.  However, we would recommend that you try to implement this first before looking at the hints on the website.
#
# Good luck!

# %% [markdown]
# ### The code below will test your command line implementation of the scrabble.py code. We've made some of these tests available for you to try!

# %%
# Code for the testing

import subprocess
from nose.tools import assert_equal 
from nose.tools import assert_true
from nose.tools import assert_greater
from nose.tools import assert_less

# %%
""" Code runs and can produce at least one error message """
# Autograde cell - do not erase/delete

# no rack error
# !python scrabble.py
# Out:
# You didn't enter a rack, please re-run and enter a rack of valid characters.

# %%
""" Does not fail due to trivial mistakes and takes correct wildcard characters """
# Autograde cell - do not erase/delete

# does not fail due to case
# !python scrabble.py "PENguin"
# Out:
# (10, penguin)
# (9, pening)
# (8, genip)
# (8, unpeg)
# (7, ingenu)
# (7, penni)
# (7, ping)
# (7, pung)
# (7, unpen)
# (7, unpin)
# (6, gip)
# (6, gup)
# (6, peg)
# (6, pein)
# (6, peni)
# (6, pig)
# (6, pine)
# (6, pug)
# (5, ennui)
# (5, genu)
# (5, gien)
# (5, ginn)
# (5, nep)
# (5, nip)
# (5, pen)
# (5, pie)
# (5, pin)
# (5, piu)
# (5, pun)
# (4, eng)
# (4, gen)
# (4, gie)
# (4, gin)
# (4, gnu)
# (4, gue)
# (4, gun)
# (4, neg)
# (4, nine)
# (4, pe)
# (4, pi)
# (4, up)
# (3, gi)
# (3, gu)
# (3, inn)
# (3, nie)
# (3, nun)
# (3, ug)
# (3, uni)
# (2, en)
# (2, in)
# (2, ne)
# (2, nu)
# (2, un)
# Total number of words: 53

# %%
# Autograde cell - do not erase/delete

# takes wildcards

# !python scrabble.py "PEN*?in"
# Out:
# (11, ziz)
# (8, pennill)
# (7, enprint)
# (7, kike)
# (7, kink)
# (7, neaping)
# (7, ninepin)
# (7, opening)
# (7, pannier)
# (7, pantine)
# (7, peaning)
# (7, peening)
# (7, peining)
# (7, pending)
# (7, penguin)
# (7, penill)
# (7, pening)
# (7, penni)
# (7, pennia)
# (7, pennied)
# (7, pennies)
# (7, pennine)
# (7, penning)
# (7, pennis)
# (7, pension)
# (7, pfennig)
# (7, pinbone)
# (7, pinene)
# (7, pinenes)
# (7, pinken)
# (7, pinkens)
# (7, pinnace)
# (7, pinnae)
# (7, pinnate)
# (7, pinned)
# (7, pinner)
# (7, pinners)
# (7, pinnet)
# (7, pinnets)
# (7, pinnie)
# (7, pinnies)
# (7, pinnoed)
# (7, pinnule)
# (7, pinones)
# (7, pitten)
# (7, pontine)
# (7, punnier)
# (7, snipes)
# (7, spines)
# (7, spinner)
# (7, spinnet)
# (7, spinney)
# (7, spinone)
# (7, tenpin)
# (7, tenpins)
# (6, alpine)
# (6, apian)
# (6, apnea)
# (6, apneic)
# (6, aspine)
# (6, dinned)
# (6, dipnet)
# (6, epigon)
# (6, fief)
# (6, fife)
# (6, genip)
# (6, genips)
# (6, gipsen)
# (6, hippen)
# (6, impend)
# (6, impone)
# (6, incept)
# (6, inept)
# (6, inspan)
# (6, instep)
# (6, kippen)
# (6, leptin)
# (6, lineup)
# (6, lippen)
# (6, loipen)
# (6, lupine)
# (6, mispen)
# (6, naping)
# (6, napkin)
# (6, nappie)
# (6, nepit)
# (6, nepits)
# (6, niff)
# (6, nipped)
# (6, nipper)
# (6, nipple)
# (6, nipter)
# (6, opine)
# (6, opined)
# (6, opines)
# (6, orpine)
# (6, paean)
# (6, pained)
# (6, pangen)
# (6, panier)
# (6, paning)
# (6, panini)
# (6, panino)
# (6, panne)
# (6, panned)
# (6, panner)
# (6, pannes)
# (6, pantie)
# (6, patine)
# (6, pectin)
# (6, peeing)
# (6, pein)
# (6, peinct)
# (6, peined)
# (6, peins)
# (6, pekin)
# (6, pekins)
# (6, penang)
# (6, pencil)
# (6, peni)
# (6, penial)
# (6, penie)
# (6, penies)
# (6, penile)
# (6, penis)
# (6, penman)
# (6, penmen)
# (6, penna)
# (6, pennae)
# (6, pennal)
# (6, penne)
# (6, penned)
# (6, penner)
# (6, pennes)
# (6, pennon)
# (6, penny)
# (6, pensil)
# (6, pepino)
# (6, pepsin)
# (6, perfin)
# (6, perkin)
# (6, pernio)
# (6, petit)
# (6, petti)
# (6, phenic)
# (6, phenix)
# (6, picene)
# (6, picine)
# (6, piecen)
# (6, pieing)
# (6, pieman)
# (6, piemen)
# (6, piend)
# (6, piends)
# (6, pigeon)
# (6, pigpen)
# (6, piment)
# (6, pinang)
# (6, pincer)
# (6, pindan)
# (6, pinder)
# (6, pine)
# (6, pineal)
# (6, pined)
# (6, pinery)
# (6, pines)
# (6, pineta)
# (6, piney)
# (6, pinged)
# (6, pinger)
# (6, pingle)
# (6, pinier)
# (6, pinies)
# (6, pining)
# (6, pinion)
# (6, pinite)
# (6, pinked)
# (6, pinker)
# (6, pinkey)
# (6, pinkie)
# (6, pinna)
# (6, pinnal)
# (6, pinnas)
# (6, pinny)
# (6, pinole)
# (6, pinon)
# (6, pinons)
# (6, pintle)
# (6, pinyin)
# (6, pinyon)
# (6, pioned)
# (6, pioner)
# (6, pioney)
# (6, pirnie)
# (6, pises)
# (6, pitmen)
# (6, pointe)
# (6, ponent)
# (6, ponied)
# (6, ponies)
# (6, pontie)
# (6, pownie)
# (6, prier)
# (6, prince)
# (6, proine)
# (6, pruine)
# (6, pterin)
# (6, puisne)
# (6, punier)
# (6, punkie)
# (6, punkin)
# (6, punned)
# (6, punner)
# (6, punnet)
# (6, purine)
# (6, pyeing)
# (6, pyning)
# (6, rapine)
# (6, repin)
# (6, repine)
# (6, repins)
# (6, ripen)
# (6, ripens)
# (6, riper)
# (6, sipes)
# (6, snipe)
# (6, sniped)
# (6, sniper)
# (6, snips)
# (6, spies)
# (6, spinae)
# (6, spine)
# (6, spined)
# (6, spinel)
# (6, spinet)
# (6, spinny)
# (6, spins)
# (6, spline)
# (6, supine)
# (6, tiepin)
# (6, uniped)
# (6, unopen)
# (6, unpen)
# (6, unpens)
# (6, unpent)
# (6, unpile)
# (6, unpin)
# (6, unpins)
# (6, unripe)
# (6, vive)
# (6, wippen)
# (5, aping)
# (5, arpen)
# (5, aspen)
# (5, bicep)
# (5, biped)
# (5, clipe)
# (5, copen)
# (5, cripe)
# (5, dined)
# (5, eff)
# (5, epee)
# (5, epic)
# (5, epics)
# (5, epris)
# (5, equip)
# (5, ginge)
# (5, gipon)
# (5, gripe)
# (5, heh)
# (5, iff)
# (5, imped)
# (5, impel)
# (5, inapt)
# (5, input)
# (5, intent)
# (5, ionone)
# (5, ippon)
# (5, kepi)
# (5, kepis)
# (5, kipe)
# (5, kipes)
# (5, lapin)
# (5, lepid)
# (5, lipe)
# (5, lipin)
# (5, loipe)
# (5, lupin)
# (5, mime)
# (5, napa)
# (5, nape)
# (5, naped)
# (5, napes)
# (5, nappe)
# (5, neap)
# (5, neaps)
# (5, neep)
# (5, neeps)
# (5, nempt)
# (5, nep)
# (5, neper)
# (5, neps)
# (5, netop)
# (5, nided)
# (5, nimps)
# (5, nip)
# (5, nipa)
# (5, nipas)
# (5, nippy)
# (5, nips)
# (5, noop)
# (5, nope)
# (5, open)
# (5, opens)
# (5, oping)
# (5, opsin)
# (5, orpin)
# (5, paeon)
# (5, pain)
# (5, pains)
# (5, paint)
# (5, paire)
# (5, paise)
# (5, pance)
# (5, pane)
# (5, paned)
# (5, panel)
# (5, panes)
# (5, panic)
# (5, panim)
# (5, paten)
# (5, patin)
# (5, paven)
# (5, pavin)
# (5, pean)
# (5, peans)
# (5, pecan)
# (5, peen)
# (5, peens)
# (5, peise)
# (5, peize)
# (5, pekan)
# (5, pell)
# (5, pelon)
# (5, pen)
# (5, penal)
# (5, pence)
# (5, pend)
# (5, pends)
# (5, pendu)
# (5, pene)
# (5, pened)
# (5, penes)
# (5, pengo)
# (5, penk)
# (5, penks)
# (5, pens)
# (5, pent)
# (5, pents)
# (5, peon)
# (5, peons)
# (5, peony)
# (5, perai)
# (5, peri)
# (5, peril)
# (5, peris)
# (5, pern)
# (5, perns)
# (5, pewit)
# (5, phene)
# (5, pheon)
# (5, phone)
# (5, pian)
# (5, piano)
# (5, pians)
# (5, pice)
# (5, pie)
# (5, piece)
# (5, pied)
# (5, pier)
# (5, piers)
# (5, piert)
# (5, pies)
# (5, piet)
# (5, pieta)
# (5, piets)
# (5, piety)
# (5, piezo)
# (5, piing)
# (5, pike)
# (5, piked)
# (5, piker)
# (5, pikes)
# (5, pikey)
# (5, pile)
# (5, pilea)
# (5, piled)
# (5, pilei)
# (5, piler)
# (5, piles)
# (5, pill)
# (5, pin)
# (5, pina)
# (5, pinas)
# (5, pinch)
# (5, ping)
# (5, pingo)
# (5, pings)
# (5, pink)
# (5, pinko)
# (5, pinks)
# (5, pinky)
# (5, pinot)
# (5, pins)
# (5, pint)
# (5, pinta)
# (5, pinto)
# (5, pints)
# (5, pinup)
# (5, piny)
# (5, pion)
# (5, pions)
# (5, piony)
# (5, pioye)
# (5, pipe)
# (5, piped)
# (5, piper)
# (5, pipes)
# (5, pipet)
# (5, pique)
# (5, pirn)
# (5, pirns)
# (5, pise)
# (5, piss)
# (5, piste)
# (5, piton)
# (5, pixel)
# (5, pixes)
# (5, pixie)
# (5, pize)
# (5, pized)
# (5, pizes)
# (5, plain)
# (5, plane)
# (5, plena)
# (5, pleon)
# (5, plie)
# (5, plied)
# (5, plier)
# (5, plies)
# (5, pling)
# (5, plink)
# (5, poind)
# (5, point)
# (5, poise)
# (5, pokie)
# (5, ponce)
# (5, pone)
# (5, pones)
# (5, poney)
# (5, poon)
# (5, potin)
# (5, powin)
# (5, preen)
# (5, preif)
# (5, prent)
# (5, price)
# (5, pride)
# (5, pried)
# (5, prief)
# (5, pries)
# (5, prime)
# (5, prink)
# (5, print)
# (5, prion)
# (5, prise)
# (5, prize)
# (5, proin)
# (5, prone)
# (5, prune)
# (5, psion)
# (5, psis)
# (5, pumie)
# (5, punce)
# (5, punji)
# (5, punny)
# (5, purin)
# (5, pyin)
# (5, pyins)
# (5, pyne)
# (5, pyned)
# (5, pynes)
# (5, pyxie)
# (5, redip)
# (5, ripe)
# (5, riped)
# (5, ripes)
# (5, sepia)
# (5, sepic)
# (5, seps)
# (5, sipe)
# (5, siped)
# (5, sips)
# (5, slipe)
# (5, sneap)
# (5, snip)
# (5, snipy)
# (5, snoep)
# (5, spain)
# (5, spane)
# (5, spean)
# (5, speil)
# (5, speir)
# (5, spend)
# (5, spent)
# (5, spice)
# (5, spide)
# (5, spie)
# (5, spied)
# (5, spiel)
# (5, spier)
# (5, spike)
# (5, spile)
# (5, spin)
# (5, spina)
# (5, spink)
# (5, spiny)
# (5, spire)
# (5, spite)
# (5, stipe)
# (5, swipe)
# (5, tapen)
# (5, tempi)
# (5, tepid)
# (5, tipt)
# (5, tripe)
# (5, umpie)
# (5, unhip)
# (5, unpeg)
# (5, unrip)
# (5, unzip)
# (5, upend)
# (5, uptie)
# (5, viper)
# (5, wipe)
# (5, wiped)
# (5, wiper)
# (5, wipes)
# (5, yipe)
# (5, yipes)
# (4, ape)
# (4, aped)
# (4, aper)
# (4, apes)
# (4, apex)
# (4, apse)
# (4, beep)
# (4, benign)
# (4, benni)
# (4, bennis)
# (4, benzin)
# (4, bib)
# (4, binmen)
# (4, binned)
# (4, blip)
# (4, boep)
# (4, bonnie)
# (4, canine)
# (4, cannie)
# (4, cape)
# (4, capi)
# (4, cep)
# (4, cepe)
# (4, ceps)
# (4, chip)
# (4, clip)
# (4, conine)
# (4, cope)
# (4, deep)
# (4, deid)
# (4, dentin)
# (4, died)
# (4, dimp)
# (4, dinner)
# (4, dinnle)
# (4, dip)
# (4, dips)
# (4, dipt)
# (4, dope)
# (4, drip)
# (4, dupe)
# (4, dynein)
# (4, eaning)
# (4, ebb)
# (4, empt)
# (4, encina)
# (4, ending)
# (4, endrin)
# (4, engine)
# (4, enjoin)
# (4, enlink)
# (4, ennui)
# (4, ennuis)
# (4, enring)
# (4, ensign)
# (4, enwind)
# (4, enzian)
# (4, eonian)
# (4, epha)
# (4, epos)
# (4, erning)
# (4, espy)
# (4, ettin)
# (4, expo)
# (4, fainne)
# (4, finned)
# (4, finner)
# (4, flip)
# (4, gape)
# (4, geep)
# (4, gimp)
# (4, ging)
# (4, ginned)
# (4, ginnel)
# (4, ginner)
# (4, gip)
# (4, gips)
# (4, grip)
# (4, heap)
# (4, help)
# (4, hemp)
# (4, hennin)
# (4, hep)
# (4, heps)
# (4, hept)
# (4, hesp)
# (4, hip)
# (4, hips)
# (4, hipt)
# (4, hope)
# (4, hype)
# (4, imp)
# (4, impi)
# (4, imps)
# (4, inane)
# (4, inaner)
# (4, inanes)
# (4, inbent)
# (4, incent)
# (4, indene)
# (4, indent)
# (4, ingenu)
# (4, ingine)
# (4, innage)
# (4, innate)
# (4, inned)
# (4, inner)
# (4, inners)
# (4, insane)
# (4, intend)
# (4, intern)
# (4, intine)
# (4, intone)
# (4, invent)
# (4, jape)
# (4, jeep)
# (4, jimp)
# (4, jinne)
# (4, jinnee)
# (4, jupe)
# (4, keep)
# (4, kelp)
# (4, kemp)
# (4, kep)
# (4, keps)
# (4, kept)
# (4, kilp)
# (4, kinone)
# (4, kip)
# (4, kipp)
# (4, kips)
# (4, knap)
# (4, knop)
# (4, kype)
# (4, leap)
# (4, leep)
# (4, lep)
# (4, leps)
# (4, lept)
# (4, lerp)
# (4, limp)
# (4, linden)
# (4, linen)
# (4, linens)
# (4, lineny)
# (4, linned)
# (4, linnet)
# (4, linney)
# (4, lip)
# (4, lipa)
# (4, lipo)
# (4, lips)
# (4, lisp)
# (4, lope)
# (4, mem)
# (4, mening)
# (4, meninx)
# (4, mim)
# (4, minnie)
# (4, mips)
# (4, mope)
# (4, nannie)
# (4, nap)
# (4, naps)
# (4, narine)
# (4, neanic)
# (4, neinei)
# (4, nerine)
# (4, newing)
# (4, nine)
# (4, nines)
# (4, ninety)
# (4, nisse)
# (4, noup)
# (4, olpe)
# (4, ondine)
# (4, onion)
# (4, online)
# (4, oop)
# (4, ope)
# (4, oped)
# (4, opes)
# (4, pace)
# (4, padi)
# (4, page)
# (4, paid)
# (4, paik)
# (4, pail)
# (4, pair)
# (4, pais)
# (4, pale)
# (4, pan)
# (4, pand)
# (4, pang)
# (4, pans)
# (4, pant)
# (4, pape)
# (4, pare)
# (4, pase)
# (4, pate)
# (4, pave)
# (4, pawn)
# (4, pe)
# (4, pea)
# (4, peag)
# (4, peak)
# (4, peal)
# (4, pear)
# (4, peas)
# (4, peat)
# (4, peba)
# (4, pec)
# (4, pech)
# (4, peck)
# (4, pecs)
# (4, ped)
# (4, peds)
# (4, pee)
# (4, peed)
# (4, peek)
# (4, peel)
# (4, peep)
# (4, peer)
# (4, pees)
# (4, peg)
# (4, pegh)
# (4, pegs)
# (4, peh)
# (4, pehs)
# (4, peke)
# (4, pela)
# (4, pele)
# (4, pelf)
# (4, pelt)
# (4, pep)
# (4, pepo)
# (4, peps)
# (4, per)
# (4, pere)
# (4, perk)
# (4, perm)
# (4, perp)
# (4, pert)
# (4, perv)
# (4, pes)
# (4, peso)
# (4, pest)
# (4, pet)
# (4, pets)
# (4, pew)
# (4, pews)
# (4, pfui)
# (4, phew)
# (4, phi)
# (4, phis)
# (4, phiz)
# (4, phon)
# (4, pi)
# (4, pia)
# (4, pial)
# (4, pias)
# (4, pic)
# (4, pica)
# (4, pick)
# (4, pics)
# (4, pig)
# (4, pigs)
# (4, pika)
# (4, piki)
# (4, pila)
# (4, pili)
# (4, pily)
# (4, pima)
# (4, pimp)
# (4, pioy)
# (4, pip)
# (4, pipa)
# (4, pipi)
# (4, pips)
# (4, pipy)
# (4, pir)
# (4, pirl)
# (4, pirs)
# (4, pis)
# (4, pish)
# (4, piso)
# (4, pit)
# (4, pita)
# (4, pith)
# (4, pits)
# (4, pity)
# (4, piu)
# (4, pium)
# (4, pix)
# (4, pixy)
# (4, plan)
# (4, plea)
# (4, pleb)
# (4, pled)
# (4, plew)
# (4, plex)
# (4, plim)
# (4, plue)
# (4, poem)
# (4, poep)
# (4, poet)
# (4, poi)
# (4, pois)
# (4, poke)
# (4, pole)
# (4, pome)
# (4, pond)
# (4, pong)
# (4, ponk)
# (4, pons)
# (4, pont)
# (4, pony)
# (4, poo)
# (4, pope)
# (4, pore)
# (4, porn)
# (4, pose)
# (4, pote)
# (4, pown)
# (4, pre)
# (4, pree)
# (4, prem)
# (4, prep)
# (4, prex)
# (4, prey)
# (4, prez)
# (4, prig)
# (4, prim)
# (4, psi)
# (4, ptui)
# (4, pube)
# (4, puce)
# (4, puer)
# (4, puir)
# (4, puke)
# (4, pule)
# (4, puli)
# (4, pun)
# (4, puna)
# (4, pung)
# (4, punk)
# (4, puns)
# (4, punt)
# (4, puny)
# (4, pure)
# (4, puri)
# (4, pye)
# (4, pyes)
# (4, pyet)
# (4, pyic)
# (4, pyre)
# (4, quep)
# (4, quip)
# (4, ranine)
# (4, rape)
# (4, reap)
# (4, renin)
# (4, renins)
# (4, rennin)
# (4, rep)
# (4, repo)
# (4, repp)
# (4, reps)
# (4, rip)
# (4, ripp)
# (4, rips)
# (4, ript)
# (4, risp)
# (4, ronnie)
# (4, rope)
# (4, rype)
# (4, sannie)
# (4, seep)
# (4, sennit)
# (4, sensi)
# (4, sept)
# (4, shinne)
# (4, ship)
# (4, sienna)
# (4, siens)
# (4, simp)
# (4, sines)
# (4, sinned)
# (4, sinner)
# (4, sinnet)
# (4, sip)
# (4, skep)
# (4, skip)
# (4, slip)
# (4, snap)
# (4, snies)
# (4, spae)
# (4, span)
# (4, spec)
# (4, sped)
# (4, spek)
# (4, spet)
# (4, spew)
# (4, spic)
# (4, spif)
# (4, spik)
# (4, spim)
# (4, spit)
# (4, spiv)
# (4, spue)
# (4, spun)
# (4, step)
# (4, supe)
# (4, sype)
# (4, tannie)
# (4, tape)
# (4, temp)
# (4, tennis)
# (4, tepa)
# (4, tinmen)
# (4, tinned)
# (4, tinner)
# (4, tinnie)
# (4, tip)
# (4, tipi)
# (4, tips)
# (4, tope)
# (4, topi)
# (4, trip)
# (4, type)
# (4, undine)
# (4, unfine)
# (4, unline)
# (4, unrein)
# (4, upon)
# (4, veep)
# (4, venin)
# (4, venine)
# (4, venins)
# (4, weep)
# (4, wept)
# (4, whip)
# (4, wimp)
# (4, winned)
# (4, winner)
# (4, winnle)
# (4, wisp)
# (4, yelp)
# (4, yep)
# (4, yeps)
# (4, yip)
# (4, yips)
# (4, ympe)
# (4, yonnie)
# (4, zep)
# (4, zeps)
# (4, zip)
# (4, zips)
# (3, aine)
# (3, ainee)
# (3, alien)
# (3, aline)
# (3, alp)
# (3, amine)
# (3, amp)
# (3, anan)
# (3, anent)
# (3, anile)
# (3, anime)
# (3, anion)
# (3, anise)
# (3, anna)
# (3, annex)
# (3, apo)
# (3, app)
# (3, apt)
# (3, asp)
# (3, avine)
# (3, azine)
# (3, bap)
# (3, begin)
# (3, bein)
# (3, being)
# (3, beni)
# (3, benis)
# (3, benne)
# (3, benny)
# (3, bien)
# (3, bine)
# (3, biner)
# (3, bines)
# (3, binge)
# (3, bonie)
# (3, bonne)
# (3, bop)
# (3, brine)
# (3, cap)
# (3, chine)
# (3, cine)
# (3, cines)
# (3, cline)
# (3, conin)
# (3, conne)
# (3, cop)
# (3, crine)
# (3, cunei)
# (3, cup)
# (3, daine)
# (3, dap)
# (3, deign)
# (3, deni)
# (3, denim)
# (3, denis)
# (3, did)
# (3, diene)
# (3, dine)
# (3, diner)
# (3, dines)
# (3, dinge)
# (3, dinna)
# (3, dizen)
# (3, djinn)
# (3, donne)
# (3, dop)
# (3, dup)
# (3, dwine)
# (3, egg)
# (3, ehing)
# (3, eigne)
# (3, eikon)
# (3, eina)
# (3, eine)
# (3, eking)
# (3, elain)
# (3, eldin)
# (3, elfin)
# (3, elint)
# (3, eloin)
# (3, elsin)
# (3, enfix)
# (3, eniac)
# (3, enlit)
# (3, ennog)
# (3, enoki)
# (3, entia)
# (3, envoi)
# (3, eosin)
# (3, ering)
# (3, exine)
# (3, exing)
# (3, eying)
# (3, faine)
# (3, fap)
# (3, feign)
# (3, feint)
# (3, feni)
# (3, fenis)
# (3, fenny)
# (3, fiend)
# (3, fient)
# (3, fine)
# (3, fined)
# (3, finer)
# (3, fines)
# (3, finny)
# (3, fop)
# (3, gap)
# (3, genic)
# (3, genie)
# (3, genii)
# (3, genny)
# (3, gien)
# (3, gig)
# (3, ginn)
# (3, ginny)
# (3, given)
# (3, grein)
# (3, gup)
# (3, gwine)
# (3, gynie)
# (3, gyp)
# (3, hap)
# (3, hemin)
# (3, henna)
# (3, henny)
# (3, hinge)
# (3, hinny)
# (3, hizen)
# (3, hop)
# (3, hup)
# (3, hyp)
# (3, ident)
# (3, igg)
# (3, imine)
# (3, inbye)
# (3, incle)
# (3, indew)
# (3, index)
# (3, indie)
# (3, indue)
# (3, inerm)
# (3, inert)
# (3, infer)
# (3, ingan)
# (3, ingle)
# (3, inion)
# (3, inked)
# (3, inker)
# (3, inkle)
# (3, inlet)
# (3, inn)
# (3, inns)
# (3, inrun)
# (3, inset)
# (3, intel)
# (3, inter)
# (3, inure)
# (3, inurn)
# (3, irone)
# (3, isnae)
# (3, jap)
# (3, jenny)
# (3, jinn)
# (3, jinni)
# (3, jinns)
# (3, kine)
# (3, kines)
# (3, kinin)
# (3, knife)
# (3, knive)
# (3, koine)
# (3, kop)
# (3, lap)
# (3, lenis)
# (3, lenti)
# (3, levin)
# (3, liane)
# (3, lien)
# (3, liens)
# (3, ligne)
# (3, liken)
# (3, limen)
# (3, line)
# (3, lined)
# (3, liner)
# (3, lines)
# (3, liney)
# (3, linin)
# (3, linn)
# (3, linns)
# (3, linny)
# (3, liven)
# (3, lop)
# (3, map)
# (3, mein)
# (3, meins)
# (3, meint)
# (3, meiny)
# (3, mien)
# (3, miens)
# (3, minae)
# (3, mince)
# (3, mine)
# (3, mined)
# (3, miner)
# (3, mines)
# (3, minge)
# (3, minke)
# (3, minny)
# (3, mixen)
# (3, mizen)
# (3, mm)
# (3, monie)
# (3, mop)
# (3, naan)
# (3, naevi)
# (3, nain)
# (3, naive)
# (3, nana)
# (3, nance)
# (3, nane)
# (3, neif)
# (3, neifs)
# (3, neigh)
# (3, neist)
# (3, neive)
# (3, nelis)
# (3, nemn)
# (3, nemns)
# (3, nene)
# (3, nenes)
# (3, neon)
# (3, neons)
# (3, ness)
# (3, nett)
# (3, nevi)
# (3, newie)
# (3, nice)
# (3, nicer)
# (3, niche)
# (3, nide)
# (3, nides)
# (3, nie)
# (3, niece)
# (3, nied)
# (3, nief)
# (3, niefs)
# (3, nies)
# (3, nieve)
# (3, nife)
# (3, nifes)
# (3, niger)
# (3, nill)
# (3, ninja)
# (3, ninny)
# (3, ninon)
# (3, ninth)
# (3, nisei)
# (3, nite)
# (3, niter)
# (3, nites)
# (3, niton)
# (3, nitre)
# (3, nixe)
# (3, nixed)
# (3, nixer)
# (3, nixes)
# (3, nixie)
# (3, noint)
# (3, noise)
# (3, nomen)
# (3, nonce)
# (3, none)
# (3, nones)
# (3, nonet)
# (3, noni)
# (3, nonis)
# (3, noon)
# (3, nudie)
# (3, numen)
# (3, nying)
# (3, olein)
# (3, onie)
# (3, onned)
# (3, op)
# (3, ops)
# (3, opt)
# (3, oup)
# (3, ovine)
# (3, pa)
# (3, pac)
# (3, pad)
# (3, pah)
# (3, pal)
# (3, pam)
# (3, pap)
# (3, par)
# (3, pas)
# (3, pat)
# (3, pav)
# (3, paw)
# (3, pax)
# (3, pay)
# (3, pho)
# (3, pht)
# (3, plu)
# (3, ply)
# (3, po)
# (3, poa)
# (3, pod)
# (3, poh)
# (3, pol)
# (3, pom)
# (3, pop)
# (3, pos)
# (3, pot)
# (3, pow)
# (3, pox)
# (3, poz)
# (3, pro)
# (3, pry)
# (3, pst)
# (3, pub)
# (3, pud)
# (3, pug)
# (3, puh)
# (3, pul)
# (3, pup)
# (3, pur)
# (3, pus)
# (3, put)
# (3, puy)
# (3, pya)
# (3, pyx)
# (3, quine)
# (3, raine)
# (3, rap)
# (3, reign)
# (3, rein)
# (3, reink)
# (3, reins)
# (3, renig)
# (3, renne)
# (3, resin)
# (3, rewin)
# (3, rhine)
# (3, rine)
# (3, rines)
# (3, rinse)
# (3, risen)
# (3, riven)
# (3, ronin)
# (3, ronne)
# (3, saine)
# (3, sap)
# (3, sdein)
# (3, segni)
# (3, seine)
# (3, seis)
# (3, sengi)
# (3, senna)
# (3, sens)
# (3, senti)
# (3, serin)
# (3, sewin)
# (3, shine)
# (3, sien)
# (3, sient)
# (3, sies)
# (3, silen)
# (3, since)
# (3, sine)
# (3, sined)
# (3, sinew)
# (3, singe)
# (3, sins)
# (3, siren)
# (3, skein)
# (3, snide)
# (3, sonne)
# (3, sop)
# (3, spa)
# (3, spy)
# (3, stein)
# (3, sup)
# (3, swine)
# (3, tap)
# (3, teind)
# (3, tenia)
# (3, tenne)
# (3, tenno)
# (3, tenny)
# (3, tenon)
# (3, tent)
# (3, thein)
# (3, thine)
# (3, tine)
# (3, tinea)
# (3, tined)
# (3, tines)
# (3, tinge)
# (3, tinny)
# (3, tint)
# (3, tite)
# (3, tonne)
# (3, top)
# (3, trine)
# (3, tup)
# (3, twine)
# (3, twp)
# (3, ump)
# (3, union)
# (3, unite)
# (3, untie)
# (3, untin)
# (3, up)
# (3, upo)
# (3, ups)
# (3, urine)
# (3, urp)
# (3, vein)
# (3, veins)
# (3, veiny)
# (3, vimen)
# (3, vine)
# (3, vined)
# (3, viner)
# (3, vines)
# (3, vinew)
# (3, visne)
# (3, vixen)
# (3, wap)
# (3, wenny)
# (3, whine)
# (3, widen)
# (3, wince)
# (3, wine)
# (3, wined)
# (3, wines)
# (3, winey)
# (3, winge)
# (3, winn)
# (3, winna)
# (3, winns)
# (3, winze)
# (3, wizen)
# (3, wop)
# (3, xenia)
# (3, xenic)
# (3, xenon)
# (3, yap)
# (3, yince)
# (3, yup)
# (3, zap)
# (3, zein)
# (3, zeins)
# (3, zine)
# (3, zineb)
# (3, zines)
# (3, zinke)
# (2, acne)
# (2, aeon)
# (2, agen)
# (2, agin)
# (2, aia)
# (2, aide)
# (2, ain)
# (2, ains)
# (2, airn)
# (2, akin)
# (2, amen)
# (2, amie)
# (2, amin)
# (2, ana)
# (2, ance)
# (2, ane)
# (2, anes)
# (2, anew)
# (2, ani)
# (2, anil)
# (2, anis)
# (2, ann)
# (2, anno)
# (2, anns)
# (2, anon)
# (2, ante)
# (2, anti)
# (2, aune)
# (2, ayin)
# (2, bane)
# (2, bani)
# (2, bean)
# (2, been)
# (2, ben)
# (2, bend)
# (2, bene)
# (2, benj)
# (2, bens)
# (2, bent)
# (2, bice)
# (2, bide)
# (2, bier)
# (2, bike)
# (2, bile)
# (2, bin)
# (2, bind)
# (2, bing)
# (2, bink)
# (2, bins)
# (2, bint)
# (2, bise)
# (2, bite)
# (2, bize)
# (2, blin)
# (2, bone)
# (2, brei)
# (2, bren)
# (2, brie)
# (2, brin)
# (2, bunn)
# (2, cain)
# (2, cane)
# (2, cann)
# (2, cedi)
# (2, ceil)
# (2, cens)
# (2, cent)
# (2, chin)
# (2, cide)
# (2, ciel)
# (2, cion)
# (2, cire)
# (2, cite)
# (2, cive)
# (2, coin)
# (2, cone)
# (2, coni)
# (2, conn)
# (2, dean)
# (2, deen)
# (2, defi)
# (2, dei)
# (2, deif)
# (2, deil)
# (2, deli)
# (2, den)
# (2, dene)
# (2, dens)
# (2, dent)
# (2, deny)
# (2, dern)
# (2, desi)
# (2, dice)
# (2, die)
# (2, dieb)
# (2, diel)
# (2, dies)
# (2, diet)
# (2, dike)
# (2, dime)
# (2, din)
# (2, ding)
# (2, dink)
# (2, dino)
# (2, dins)
# (2, dint)
# (2, dire)
# (2, dite)
# (2, dive)
# (2, djin)
# (2, doen)
# (2, done)
# (2, dune)
# (2, dyne)
# (2, ean)
# (2, eans)
# (2, earn)
# (2, ebon)
# (2, edit)
# (2, een)
# (2, eevn)
# (2, egis)
# (2, eide)
# (2, eik)
# (2, eiks)
# (2, eild)
# (2, eish)
# (2, elan)
# (2, elhi)
# (2, ell)
# (2, emic)
# (2, emir)
# (2, emit)
# (2, en)
# (2, end)
# (2, ends)
# (2, ene)
# (2, enes)
# (2, enew)
# (2, eng)
# (2, engs)
# (2, enol)
# (2, enow)
# (2, ens)
# (2, enuf)
# (2, envy)
# (2, eoan)
# (2, eon)
# (2, eons)
# (2, eric)
# (2, ern)
# (2, erne)
# (2, erns)
# (2, err)
# (2, esne)
# (2, ess)
# (2, eten)
# (2, etic)
# (2, etna)
# (2, etui)
# (2, euoi)
# (2, even)
# (2, evil)
# (2, exit)
# (2, exon)
# (2, eyen)
# (2, eyne)
# (2, fain)
# (2, fane)
# (2, feen)
# (2, feis)
# (2, fen)
# (2, fend)
# (2, fens)
# (2, fent)
# (2, fern)
# (2, fice)
# (2, fie)
# (2, fier)
# (2, fike)
# (2, file)
# (2, fin)
# (2, find)
# (2, fini)
# (2, fink)
# (2, fino)
# (2, fins)
# (2, fire)
# (2, firn)
# (2, five)
# (2, foen)
# (2, foin)
# (2, fone)
# (2, gaen)
# (2, gain)
# (2, gane)
# (2, gean)
# (2, geit)
# (2, gen)
# (2, gena)
# (2, gene)
# (2, gens)
# (2, gent)
# (2, genu)
# (2, gibe)
# (2, gie)
# (2, gied)
# (2, gies)
# (2, gin)
# (2, gink)
# (2, gins)
# (2, girn)
# (2, gite)
# (2, give)
# (2, glei)
# (2, glen)
# (2, gone)
# (2, gren)
# (2, grin)
# (2, haen)
# (2, hain)
# (2, heid)
# (2, heil)
# (2, heir)
# (2, hen)
# (2, hend)
# (2, hens)
# (2, hent)
# (2, hern)
# (2, hewn)
# (2, hide)
# (2, hie)
# (2, hied)
# (2, hies)
# (2, hike)
# (2, hin)
# (2, hind)
# (2, hing)
# (2, hins)
# (2, hint)
# (2, hire)
# (2, hisn)
# (2, hive)
# (2, hone)
# (2, hyen)
# (2, ibex)
# (2, ice)
# (2, iced)
# (2, icer)
# (2, ices)
# (2, icon)
# (2, ide)
# (2, idea)
# (2, idee)
# (2, idem)
# (2, ides)
# (2, idle)
# (2, ikan)
# (2, ikon)
# (2, ilea)
# (2, ilex)
# (2, ill)
# (2, in)
# (2, inby)
# (2, inch)
# (2, info)
# (2, ingo)
# (2, inia)
# (2, ink)
# (2, inks)
# (2, inky)
# (2, inly)
# (2, inro)
# (2, ins)
# (2, inti)
# (2, into)
# (2, ion)
# (2, ions)
# (2, ire)
# (2, ired)
# (2, ires)
# (2, iron)
# (2, isle)
# (2, isna)
# (2, item)
# (2, iure)
# (2, jane)
# (2, jann)
# (2, jean)
# (2, jedi)
# (2, jeon)
# (2, jibe)
# (2, jin)
# (2, jink)
# (2, jins)
# (2, jinx)
# (2, jive)
# (2, join)
# (2, kaie)
# (2, kain)
# (2, kane)
# (2, keen)
# (2, keir)
# (2, ken)
# (2, keno)
# (2, kens)
# (2, kent)
# (2, kern)
# (2, kibe)
# (2, kief)
# (2, kier)
# (2, kiln)
# (2, kin)
# (2, kina)
# (2, kind)
# (2, king)
# (2, kino)
# (2, kins)
# (2, kirn)
# (2, kite)
# (2, knee)
# (2, knew)
# (2, knit)
# (2, kune)
# (2, kyne)
# (2, lain)
# (2, lane)
# (2, lean)
# (2, lei)
# (2, leir)
# (2, leis)
# (2, lend)
# (2, leng)
# (2, leno)
# (2, lens)
# (2, lent)
# (2, lice)
# (2, lie)
# (2, lied)
# (2, lief)
# (2, lier)
# (2, lies)
# (2, lieu)
# (2, life)
# (2, like)
# (2, lime)
# (2, limn)
# (2, lin)
# (2, lind)
# (2, ling)
# (2, link)
# (2, lino)
# (2, lins)
# (2, lint)
# (2, liny)
# (2, lion)
# (2, lire)
# (2, lite)
# (2, live)
# (2, loin)
# (2, lone)
# (2, lune)
# (2, lwei)
# (2, lyne)
# (2, main)
# (2, mane)
# (2, mani)
# (2, mean)
# (2, men)
# (2, mend)
# (2, mene)
# (2, meng)
# (2, meno)
# (2, ment)
# (2, menu)
# (2, meri)
# (2, mice)
# (2, mike)
# (2, mile)
# (2, mina)
# (2, mind)
# (2, ming)
# (2, mini)
# (2, mink)
# (2, mino)
# (2, mint)
# (2, minx)
# (2, miny)
# (2, mire)
# (2, mise)
# (2, mite)
# (2, muni)
# (2, nabe)
# (2, nae)
# (2, naif)
# (2, naik)
# (2, nail)
# (2, name)
# (2, nan)
# (2, nans)
# (2, naoi)
# (2, nare)
# (2, nave)
# (2, naze)
# (2, nazi)
# (2, ne)
# (2, neal)
# (2, near)
# (2, neat)
# (2, neb)
# (2, nebs)
# (2, neck)
# (2, ned)
# (2, neds)
# (2, nee)
# (2, need)
# (2, neem)
# (2, nef)
# (2, nefs)
# (2, neg)
# (2, negs)
# (2, nek)
# (2, neks)
# (2, nema)
# (2, nerd)
# (2, nerk)
# (2, nesh)
# (2, nest)
# (2, net)
# (2, nete)
# (2, nets)
# (2, neuk)
# (2, neum)
# (2, neve)
# (2, new)
# (2, news)
# (2, newt)
# (2, next)
# (2, nib)
# (2, nibs)
# (2, nick)
# (2, nid)
# (2, nidi)
# (2, nids)
# (2, nigh)
# (2, nil)
# (2, nils)
# (2, nim)
# (2, nimb)
# (2, nims)
# (2, nirl)
# (2, nis)
# (2, nish)
# (2, nisi)
# (2, nit)
# (2, nits)
# (2, nix)
# (2, nixy)
# (2, node)
# (2, nodi)
# (2, noel)
# (2, noes)
# (2, noil)
# (2, noir)
# (2, nole)
# (2, nome)
# (2, non)
# (2, nona)
# (2, nong)
# (2, noo)
# (2, nori)
# (2, nose)
# (2, note)
# (2, noun)
# (2, nown)
# (2, nude)
# (2, nuke)
# (2, nun)
# (2, nuns)
# (2, nye)
# (2, nyed)
# (2, nyes)
# (2, oink)
# (2, oint)
# (2, omen)
# (2, once)
# (2, one)
# (2, oner)
# (2, ones)
# (2, ono)
# (2, oon)
# (2, oven)
# (2, oxen)
# (2, quin)
# (2, rain)
# (2, rani)
# (2, rean)
# (2, reen)
# (2, rei)
# (2, reif)
# (2, reik)
# (2, reis)
# (2, ren)
# (2, rend)
# (2, renk)
# (2, rens)
# (2, rent)
# (2, reny)
# (2, rice)
# (2, ride)
# (2, riel)
# (2, riem)
# (2, rife)
# (2, rile)
# (2, rime)
# (2, rin)
# (2, rind)
# (2, ring)
# (2, rink)
# (2, rins)
# (2, rise)
# (2, rite)
# (2, rive)
# (2, roin)
# (2, rone)
# (2, ruin)
# (2, rune)
# (2, sain)
# (2, sane)
# (2, sean)
# (2, seen)
# (2, sei)
# (2, seif)
# (2, seik)
# (2, seil)
# (2, seir)
# (2, semi)
# (2, sen)
# (2, sena)
# (2, send)
# (2, sene)
# (2, sent)
# (2, sewn)
# (2, shin)
# (2, sice)
# (2, side)
# (2, sign)
# (2, sike)
# (2, sile)
# (2, sin)
# (2, sind)
# (2, sing)
# (2, sinh)
# (2, sink)
# (2, sire)
# (2, sis)
# (2, site)
# (2, size)
# (2, sken)
# (2, skin)
# (2, sneb)
# (2, sned)
# (2, snee)
# (2, snib)
# (2, snig)
# (2, snit)
# (2, snye)
# (2, sone)
# (2, sten)
# (2, stie)
# (2, sunn)
# (2, syen)
# (2, syne)
# (2, tain)
# (2, tane)
# (2, teen)
# (2, teil)
# (2, ten)
# (2, tend)
# (2, tene)
# (2, tens)
# (2, tern)
# (2, tet)
# (2, then)
# (2, thin)
# (2, tice)
# (2, tide)
# (2, tie)
# (2, tied)
# (2, tier)
# (2, ties)
# (2, tige)
# (2, tike)
# (2, tile)
# (2, time)
# (2, tin)
# (2, tind)
# (2, ting)
# (2, tink)
# (2, tins)
# (2, tiny)
# (2, tire)
# (2, tit)
# (2, tone)
# (2, trie)
# (2, trin)
# (2, tune)
# (2, twin)
# (2, tyin)
# (2, tyne)
# (2, unai)
# (2, unbe)
# (2, unce)
# (2, unci)
# (2, unde)
# (2, uni)
# (2, unis)
# (2, unit)
# (2, vain)
# (2, vane)
# (2, veil)
# (2, vena)
# (2, vend)
# (2, vent)
# (2, viae)
# (2, vibe)
# (2, vice)
# (2, vide)
# (2, vie)
# (2, vied)
# (2, vier)
# (2, vies)
# (2, view)
# (2, vile)
# (2, vin)
# (2, vina)
# (2, vino)
# (2, vins)
# (2, vint)
# (2, viny)
# (2, vire)
# (2, vise)
# (2, vite)
# (2, vlei)
# (2, wain)
# (2, wane)
# (2, wean)
# (2, ween)
# (2, weid)
# (2, weil)
# (2, weir)
# (2, wen)
# (2, wena)
# (2, wend)
# (2, wens)
# (2, went)
# (2, when)
# (2, whin)
# (2, wice)
# (2, wide)
# (2, wiel)
# (2, wife)
# (2, wile)
# (2, win)
# (2, wind)
# (2, wing)
# (2, wink)
# (2, wino)
# (2, wins)
# (2, winy)
# (2, wire)
# (2, wise)
# (2, wite)
# (2, wive)
# (2, wren)
# (2, wynn)
# (2, yean)
# (2, yen)
# (2, yens)
# (2, yeti)
# (2, yike)
# (2, yin)
# (2, yins)
# (2, yite)
# (2, yoni)
# (2, zin)
# (2, zinc)
# (2, zing)
# (2, zins)
# (2, zite)
# (2, zone)
# (1, aa)
# (1, ace)
# (1, ae)
# (1, age)
# (1, ahi)
# (1, ai)
# (1, aid)
# (1, ail)
# (1, aim)
# (1, air)
# (1, ais)
# (1, ait)
# (1, ake)
# (1, ale)
# (1, ami)
# (1, an)
# (1, and)
# (1, ant)
# (1, any)
# (1, are)
# (1, ate)
# (1, aue)
# (1, ave)
# (1, awe)
# (1, awn)
# (1, axe)
# (1, aye)
# (1, ban)
# (1, be)
# (1, bed)
# (1, bee)
# (1, beg)
# (1, bel)
# (1, bes)
# (1, bet)
# (1, bey)
# (1, bez)
# (1, bi)
# (1, bid)
# (1, big)
# (1, bio)
# (1, bis)
# (1, bit)
# (1, biz)
# (1, boi)
# (1, bon)
# (1, bun)
# (1, bye)
# (1, can)
# (1, cee)
# (1, cel)
# (1, che)
# (1, chi)
# (1, cid)
# (1, cig)
# (1, cis)
# (1, cit)
# (1, con)
# (1, cue)
# (1, dae)
# (1, dan)
# (1, de)
# (1, deb)
# (1, dee)
# (1, def)
# (1, deg)
# (1, del)
# (1, dev)
# (1, dew)
# (1, dex)
# (1, dey)
# (1, di)
# (1, dib)
# (1, dif)
# (1, dig)
# (1, dim)
# (1, dis)
# (1, dit)
# (1, div)
# (1, doe)
# (1, don)
# (1, due)
# (1, dui)
# (1, dun)
# (1, dye)
# (1, ea)
# (1, ear)
# (1, eas)
# (1, eat)
# (1, eau)
# (1, ech)
# (1, eco)
# (1, ecu)
# (1, ed)
# (1, edh)
# (1, eds)
# (1, ee)
# (1, eek)
# (1, eel)
# (1, ef)
# (1, efs)
# (1, eft)
# (1, ego)
# (1, eh)
# (1, ehs)
# (1, eke)
# (1, el)
# (1, eld)
# (1, elf)
# (1, elk)
# (1, elm)
# (1, els)
# (1, elt)
# (1, em)
# (1, eme)
# (1, emo)
# (1, ems)
# (1, emu)
# (1, er)
# (1, era)
# (1, ere)
# (1, erf)
# (1, erg)
# (1, erk)
# (1, ers)
# (1, es)
# (1, est)
# (1, et)
# (1, eta)
# (1, eth)
# (1, euk)
# (1, eve)
# (1, evo)
# (1, ewe)
# (1, ewk)
# (1, ewt)
# (1, ex)
# (1, exo)
# (1, eye)
# (1, fae)
# (1, fan)
# (1, fe)
# (1, fed)
# (1, fee)
# (1, feg)
# (1, feh)
# (1, fem)
# (1, fer)
# (1, fes)
# (1, fet)
# (1, feu)
# (1, few)
# (1, fey)
# (1, fez)
# (1, fib)
# (1, fid)
# (1, fig)
# (1, fil)
# (1, fir)
# (1, fit)
# (1, fix)
# (1, fiz)
# (1, foe)
# (1, fon)
# (1, fun)
# (1, gae)
# (1, gan)
# (1, ged)
# (1, gee)
# (1, gel)
# (1, gem)
# (1, geo)
# (1, get)
# (1, gey)
# (1, ghi)
# (1, gi)
# (1, gib)
# (1, gid)
# (1, gif)
# (1, gio)
# (1, gis)
# (1, git)
# (1, gnu)
# (1, goe)
# (1, gon)
# (1, gue)
# (1, gun)
# (1, hae)
# (1, han)
# (1, he)
# (1, hem)
# (1, her)
# (1, hes)
# (1, het)
# (1, hew)
# (1, hex)
# (1, hey)
# (1, hi)
# (1, hic)
# (1, hid)
# (1, him)
# (1, his)
# (1, hit)
# (1, hoe)
# (1, hoi)
# (1, hon)
# (1, hue)
# (1, hui)
# (1, hun)
# (1, hye)
# (1, ich)
# (1, ick)
# (1, icy)
# (1, id)
# (1, ids)
# (1, if)
# (1, ifs)
# (1, ilk)
# (1, io)
# (1, ios)
# (1, irk)
# (1, is)
# (1, ish)
# (1, ism)
# (1, iso)
# (1, it)
# (1, ita)
# (1, its)
# (1, ivy)
# (1, iwi)
# (1, jai)
# (1, jee)
# (1, jet)
# (1, jeu)
# (1, jew)
# (1, jib)
# (1, jig)
# (1, jiz)
# (1, joe)
# (1, jun)
# (1, kae)
# (1, kai)
# (1, kea)
# (1, keb)
# (1, ked)
# (1, kef)
# (1, keg)
# (1, ket)
# (1, kex)
# (1, key)
# (1, khi)
# (1, ki)
# (1, kid)
# (1, kif)
# (1, kir)
# (1, kis)
# (1, kit)
# (1, koi)
# (1, kon)
# (1, kue)
# (1, kye)
# (1, lea)
# (1, led)
# (1, lee)
# (1, leg)
# (1, lek)
# (1, les)
# (1, let)
# (1, leu)
# (1, lev)
# (1, lew)
# (1, lex)
# (1, ley)
# (1, lez)
# (1, li)
# (1, lib)
# (1, lid)
# (1, lig)
# (1, lis)
# (1, lit)
# (1, lye)
# (1, mae)
# (1, man)
# (1, me)
# (1, med)
# (1, mee)
# (1, meg)
# (1, mel)
# (1, mes)
# (1, met)
# (1, meu)
# (1, mew)
# (1, mi)
# (1, mib)
# (1, mic)
# (1, mid)
# (1, mig)
# (1, mil)
# (1, mir)
# (1, mis)
# (1, mix)
# (1, miz)
# (1, mna)
# (1, moe)
# (1, moi)
# (1, mon)
# (1, mun)
# (1, na)
# (1, nab)
# (1, nag)
# (1, nah)
# (1, nam)
# (1, nas)
# (1, nat)
# (1, naw)
# (1, nay)
# (1, no)
# (1, nob)
# (1, nod)
# (1, nog)
# (1, noh)
# (1, nom)
# (1, nor)
# (1, nos)
# (1, not)
# (1, now)
# (1, nox)
# (1, noy)
# (1, nth)
# (1, nu)
# (1, nub)
# (1, nur)
# (1, nus)
# (1, nut)
# (1, ny)
# (1, nys)
# (1, obe)
# (1, obi)
# (1, ode)
# (1, oe)
# (1, oes)
# (1, oi)
# (1, oik)
# (1, oil)
# (1, oke)
# (1, ole)
# (1, on)
# (1, ons)
# (1, ony)
# (1, oo)
# (1, ore)
# (1, ose)
# (1, owe)
# (1, own)
# (1, oye)
# (1, qi)
# (1, qis)
# (1, rai)
# (1, ran)
# (1, re)
# (1, reb)
# (1, rec)
# (1, red)
# (1, ree)
# (1, ref)
# (1, reg)
# (1, reh)
# (1, rem)
# (1, reo)
# (1, res)
# (1, ret)
# (1, rev)
# (1, rew)
# (1, rex)
# (1, rez)
# (1, ria)
# (1, rib)
# (1, rid)
# (1, rif)
# (1, rig)
# (1, rim)
# (1, rit)
# (1, riz)
# (1, roe)
# (1, rue)
# (1, run)
# (1, rye)
# (1, sae)
# (1, sai)
# (1, san)
# (1, sea)
# (1, sec)
# (1, sed)
# (1, see)
# (1, seg)
# (1, sel)
# (1, ser)
# (1, set)
# (1, sew)
# (1, sex)
# (1, sey)
# (1, sez)
# (1, she)
# (1, si)
# (1, sib)
# (1, sic)
# (1, sif)
# (1, sik)
# (1, sim)
# (1, sir)
# (1, sit)
# (1, six)
# (1, ski)
# (1, sny)
# (1, son)
# (1, sri)
# (1, sue)
# (1, sui)
# (1, sun)
# (1, sye)
# (1, syn)
# (1, tae)
# (1, tai)
# (1, tan)
# (1, te)
# (1, tea)
# (1, tec)
# (1, ted)
# (1, tee)
# (1, tef)
# (1, teg)
# (1, tel)
# (1, tes)
# (1, tew)
# (1, tex)
# (1, the)
# (1, ti)
# (1, tic)
# (1, tid)
# (1, tig)
# (1, til)
# (1, tis)
# (1, tix)
# (1, toe)
# (1, ton)
# (1, tui)
# (1, tun)
# (1, tye)
# (1, uey)
# (1, uke)
# (1, ule)
# (1, un)
# (1, uns)
# (1, ure)
# (1, urn)
# (1, use)
# (1, ute)
# (1, vae)
# (1, van)
# (1, vee)
# (1, veg)
# (1, vet)
# (1, vex)
# (1, via)
# (1, vid)
# (1, vig)
# (1, vim)
# (1, vis)
# (1, voe)
# (1, wae)
# (1, wai)
# (1, wan)
# (1, we)
# (1, web)
# (1, wed)
# (1, wee)
# (1, wem)
# (1, wet)
# (1, wex)
# (1, wey)
# (1, wig)
# (1, wis)
# (1, wit)
# (1, wiz)
# (1, woe)
# (1, won)
# (1, wye)
# (1, wyn)
# (1, xi)
# (1, xis)
# (1, yae)
# (1, ye)
# (1, yea)
# (1, yeh)
# (1, yes)
# (1, yet)
# (1, yew)
# (1, yex)
# (1, yid)
# (1, yon)
# (1, zea)
# (1, zed)
# (1, zee)
# (1, zek)
# (1, zel)
# (1, zex)
# (1, zig)
# (1, zit)
# (0, ab)
# (0, ad)
# (0, ag)
# (0, ah)
# (0, al)
# (0, am)
# (0, ar)
# (0, as)
# (0, at)
# (0, aw)
# (0, ax)
# (0, ay)
# (0, ba)
# (0, bo)
# (0, by)
# (0, ch)
# (0, da)
# (0, do)
# (0, fa)
# (0, fy)
# (0, go)
# (0, gu)
# (0, ha)
# (0, hm)
# (0, ho)
# (0, ja)
# (0, jo)
# (0, ka)
# (0, ko)
# (0, ky)
# (0, la)
# (0, lo)
# (0, ma)
# (0, mo)
# (0, mu)
# (0, my)
# (0, ob)
# (0, od)
# (0, of)
# (0, oh)
# (0, om)
# (0, or)
# (0, os)
# (0, ou)
# (0, ow)
# (0, ox)
# (0, oy)
# (0, sh)
# (0, so)
# (0, st)
# (0, ta)
# (0, to)
# (0, ug)
# (0, uh)
# (0, um)
# (0, ur)
# (0, us)
# (0, ut)
# (0, wo)
# (0, xu)
# (0, ya)
# (0, yo)
# (0, yu)
# (0, za)
# (0, zo)
# Total number of words: 2734

# %%
""" Produces a list of all words and scores that matches our expectations """
# Autograde cell - do not erase/delete

# The way windows and mac end lines is different 
# - windows adds a \r\n to each line 
# - mac/linux adds just a \n to each line
# The autograder will detect the system platform and use that to determine the 'correct' solution

# The code below is shown here so you know how the autograder works
# Try this block to see if your solution matches
# If your answer looks like it matches but still throws an 'autograder' error, please to double check your answer BUT 
# The purpose of the assignment isn't to make your code match the autograder - if you answer is correct it will be graded so 
# We will check every answer the autograder deems is incorrect

import platform

# test whether your output matches our expectation
cmd = ['python', 'scrabble.py', 'Penguin']
test = bytes.decode(subprocess.Popen(cmd, stdout=subprocess.PIPE).communicate()[0])

if platform.system() == 'Windows':
    solution = '(10, penguin)\r\n(9, pening)\r\n(8, genip)\r\n(8, unpeg)\r\n(7, ingenu)\r\n(7, penni)\r\n(7, ping)\r\n(7, pung)\r\n(7, unpen)\r\n(7, unpin)\r\n(6, gip)\r\n(6, gup)\r\n(6, peg)\r\n(6, pein)\r\n(6, peni)\r\n(6, pig)\r\n(6, pine)\r\n(6, pug)\r\n(5, ennui)\r\n(5, genu)\r\n(5, gien)\r\n(5, ginn)\r\n(5, nep)\r\n(5, nip)\r\n(5, pen)\r\n(5, pie)\r\n(5, pin)\r\n(5, piu)\r\n(5, pun)\r\n(4, eng)\r\n(4, gen)\r\n(4, gie)\r\n(4, gin)\r\n(4, gnu)\r\n(4, gue)\r\n(4, gun)\r\n(4, neg)\r\n(4, nine)\r\n(4, pe)\r\n(4, pi)\r\n(4, up)\r\n(3, gi)\r\n(3, gu)\r\n(3, inn)\r\n(3, nie)\r\n(3, nun)\r\n(3, ug)\r\n(3, uni)\r\n(2, en)\r\n(2, in)\r\n(2, ne)\r\n(2, nu)\r\n(2, un)\r\nTotal number of words: 53\r\n'
else:
    solution = '(10, penguin)\n(9, pening)\n(8, genip)\n(8, unpeg)\n(7, ingenu)\n(7, penni)\n(7, ping)\n(7, pung)\n(7, unpen)\n(7, unpin)\n(6, gip)\n(6, gup)\n(6, peg)\n(6, pein)\n(6, peni)\n(6, pig)\n(6, pine)\n(6, pug)\n(5, ennui)\n(5, genu)\n(5, gien)\n(5, ginn)\n(5, nep)\n(5, nip)\n(5, pen)\n(5, pie)\n(5, pin)\n(5, piu)\n(5, pun)\n(4, eng)\n(4, gen)\n(4, gie)\n(4, gin)\n(4, gnu)\n(4, gue)\n(4, gun)\n(4, neg)\n(4, nine)\n(4, pe)\n(4, pi)\n(4, up)\n(3, gi)\n(3, gu)\n(3, inn)\n(3, nie)\n(3, nun)\n(3, ug)\n(3, uni)\n(2, en)\n(2, in)\n(2, ne)\n(2, nu)\n(2, un)\nTotal number of words: 53\n'

print("\nDoes your output match our expectation?", test == solution)

# %%
""" The code should run in less than 30 seconds """
# Autograde cell - do not erase/delete

import time
start = time.time()

#test the code in the command line
cmd = ['python', 'scrabble.py', 'PENGU*?']
out = bytes.decode(subprocess.Popen(cmd, stdout=subprocess.PIPE).communicate()[0])

tot_time = time.time() - start
print('Total time was {} seconds'.format(tot_time))
assert_less(tot_time, 30)

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
"""Implement extra credit call run the code here
   If this cell isnt filled out - we'll assume the extra credit wasn't done
   Please write a comment on how to use your extra credit syntax and any assumptions also!
"""

# YOUR CODE HERE
raise NotImplementedError()

#I didn't incorporate this code into my actual main script because it didn't end up working but was told that if I at least put in some comments as to what I was planning to do, there would be some extra credit points awarded so below is what I had in mind:

import getopt

#Get the arguments from the command-line except the filename. The goal was to take additional arguments and put on flags to check if the word could be formed.

o = sys.argv[1:]
letter = ""
position = ""

try:
    # Define the getopt parameters
    opts, args = getopt.getopt(o, 'tl:tp', ['letter =', 'position =']
    # Check if the command-line inputs were entered in the correct format: "<rack>" "<letter>" "<position>" where the arguments are a single letter string and the position it should be in
    if len(opts) == 0:
        print('usage: scrabble.py -tl "tuple letter" -tp "tuple position"')
    else:
        for opt, arg in opts:
            o = o[:tp]+tl+o[tp+1:]

except getopt.GetoptError:
    "To print something useful if the "<rack>" "<letter>" "<position>" were entered in an incorrect format"
    print('usage: scrabble.py -tl "tuple letter" -tp "tuple position"')
    sys.exit(2)
                               
#If the above portion of the code worked, I was planning on also updating my error handling statements in the main script to consider these additional arguments.

# %% [markdown]
# ## If you have feedback for this homework, please submit it using the link below:
#
# http://goo.gl/forms/74yCiQTf6k
